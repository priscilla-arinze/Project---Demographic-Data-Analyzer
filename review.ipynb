# %% [markdown]
# # Python Review (NewBoston)

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(filename="test.png")

# %%
Image(filename="test.png")

# %% [markdown]
# <img src="test.png" width=60 height=60 />

# %%
print("yuh")
# Out:
# yuh

# %% [markdown]
# ![title](test.png)
